# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/raw/store_kpi.csv') # Load the dataset
df.head() # Display the first few rows of the dataset

# Data Cleaning
df.info() # Check for missing values
df.isnull().sum() # Count missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61322 entries, 0 to 61321
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dealer_id                61322 non-null  object
#  1   month                    61322 non-null  object
#  2   total_ad_spend           61322 non-null  float64
#  3   search_ad_spend          61322 non-null  float64
#  4   display_ad_spend         61322 non-null  float64
#  5   social_ad_spend          61322 non-null  float64
#  6   video_ad_spend           61322 non-null  float64
#  7   pmax_ad_spend            61322 non-null  float64
#  8   search_ad_impressions    61322 non-null  float64
#  9   display_ad_impressions   61322 non-null  float64
#  10  social_ad_impressions    61322 non-null  float64
#  11  video_ad_impressions     61322 non-null  float64
#  12  pmax_ad_impressions      61322 non-null  float64
#  13  search_ad_clicks         61322 non-null  float64
#  14  display_ad_clicks        61322 non-null  float64
#  15  social_ad_clicks         61322 non-null  float64
#  16  video_ad_clicks          61322 non-null  float64
#  17  pmax_ad_clicks           61322 non-null  float64
#  18  search_ad_visits         61322 non-null  float64
#  19  display_ad_visits        61322 non-null  float64
#  20  social_ad_visits         61322 non-null  float64
#  21  video_ad_visits          61322 non-null  float64
#  22  pmax_ad_visits           61322 non-null  float64
#  23  website_visits           61322 non-null  float64
#  24  website_return_visits    61322 non-null  float64
#  25  website_new_vdps         61322 non-null  float64
#  26  website_new_searches     61322 non-null  float64
#  27  website_engagement_rate  61322 non-null  float64
#  28  website_engagements      61322 non-null  float64
#  29  website_action_rate      61322 non-null  float64
#  30  website_actions          61322 non-null  float64
#  31  lead_volume              61322 non-null  float64
#  32  unique_lead_count        61322 non-null  float64
#  33  lead_close_rate_30day    61322 non-null  float64
#  34  lead_response_rate       61322 non-null  float64
#  35  lead_appointment_rate    61322 non-null  float64
#  36  sales                    61322 non-null  float64
# dtypes: float64(35), object(2)
# memory usage: 17.3+ MB
# dealer_id                  0
# month                      0
# total_ad_spend             0
# search_ad_spend            0
# display_ad_spend           0
# social_ad_spend            0
# video_ad_spend             0
# pmax_ad_spend              0
# search_ad_impressions      0
# display_ad_impressions     0
# social_ad_impressions      0
# video_ad_impressions       0
# pmax_ad_impressions        0
# search_ad_clicks           0
# display_ad_clicks          0
# social_ad_clicks           0
# video_ad_clicks            0
# pmax_ad_clicks             0
# search_ad_visits           0
# display_ad_visits          0
# social_ad_visits           0
# video_ad_visits            0
# pmax_ad_visits             0
# website_visits             0
# website_return_visits      0
# website_new_vdps           0
# website_new_searches       0
# website_engagement_rate    0
# website_engagements        0
# website_action_rate        0
# website_actions            0
# lead_volume                0
# unique_lead_count          0
# lead_close_rate_30day      0
# lead_response_rate         0
# lead_appointment_rate      0
# sales                      0
# dtype: int64

# %%
# Column month to datetime
df['month'] = pd.to_datetime(df['month'])
# Column Year
df['year'] = df['month'].dt.year
# Column Month
df['month_num'] = df['month'].dt.month
df['quarter'] = df['month'].dt.quarter

print(f"Time range: {df['month'].min()} to {df['month'].max()}")
print(f"Unique dealer count: {df['store_id'].nunique()}")
# Out:
# Time range: 2023-10-01 00:00:00+00:00 to 2025-09-01 00:00:00+00:00
# Unique dealer count: 2557

# %%
# Key Metrics
# 1. Ad Spend
# 2. Website Visits
# 3. Leads
# 4. Sales

key_metrics = ['total_ad_spend', 'website_visits', 'lead_volume', 'sales']
# Calculate monthly totals for each key metric
monthly_totals = df.groupby(['year', 'month_num'])[key_metrics].sum()

# Calculate quarterly totals for each key metric
quarterly_totals = df.groupby(['year', 'quarter'])[key_metrics].sum()

# Calculate yearly totals for each key metric
yearly_totals = df.groupby('year')[key_metrics].sum()

print("Key metrics:")
df[key_metrics].describe()
# Out:
# Key metrics:
#        total_ad_spend  website_visits   lead_volume         sales
# count    61322.000000    61322.000000  61322.000000  61322.000000
# mean      4070.355625    14239.716366     42.283438     28.131274
# std       9557.537942    15556.409717     63.104217     30.419416
# min          0.000000        0.000000      0.000000      0.000000
# 25%          0.000000     3608.500000      7.000000      8.000000
# 50%        103.675000     9737.000000     22.000000     19.000000
# 75%       4545.307500    19772.500000     54.000000     39.000000
# max     868687.300000   226610.000000   1406.000000    438.000000

# %%
print(monthly_totals)
print(quarterly_totals)
print(yearly_totals)
# Out:
#                 total_ad_spend  website_visits  lead_volume    sales
# year month_num
# 2023 10           0.000000e+00      31520084.0     105622.0  75357.0
#      11           0.000000e+00      30749058.0     111144.0  73092.0
#      12           0.000000e+00      33568534.0     116354.0  76434.0
# 2024 1            0.000000e+00      39332124.0     110008.0  63861.0
#      2            0.000000e+00      37193894.0     106124.0  63049.0
#      3            0.000000e+00      38405552.0     118451.0  76111.0
#      4            0.000000e+00      35587545.0     104913.0  69284.0
#      5            0.000000e+00      33834689.0     109326.0  78021.0
#      6            1.058253e+07      33201377.0     106327.0  68334.0
#      7            1.284390e+07      34563338.0     101267.0  68436.0
#      8            1.236029e+07      34701546.0     109777.0  74121.0
#      9            1.275385e+07      33690231.0     101617.0  72179.0
#      10           1.823180e+07      37943759.0     119427.0  79565.0
#      11           1.697720e+07      37188748.0     112244.0  68478.0
#      12           1.705513e+07      39295971.0     114170.0  78780.0
# 2025 1            1.545677e+07      40804983.0     104443.0  65976.0
#      2            1.672246e+07      37871000.0      98291.0  66123.0
#      3            1.724861e+07      40665501.0     114419.0  78225.0
#      4            1.694513e+07      38633806.0     112808.0  78219.0
#      5            1.698142e+07      36857546.0     108717.0  71033.0
#      6            1.800107e+07      35784697.0     102153.0  68140.0
#      7            1.709933e+07      38662007.0     105376.0  71010.0
#      8            1.664926e+07      38798475.0      98476.0  63345.0
#      9            1.369360e+07      34353422.0     101451.0  77893.0
#               total_ad_spend  website_visits  lead_volume     sales
# year quarter
# 2023 4          0.000000e+00      95837676.0     333120.0  224883.0
# 2024 1          0.000000e+00     114931570.0     334583.0  203021.0
#      2          1.058253e+07     102623611.0     320566.0  215639.0
#      3          3.795804e+07     102955115.0     312661.0  214736.0
#      4          5.226413e+07     114428478.0     345841.0  226823.0
# 2025 1          4.942783e+07     119341484.0     317153.0  210324.0
#      2          5.192763e+07     111276049.0     323678.0  217392.0
#      3          4.744219e+07     111813904.0     305303.0  212248.0
#       total_ad_spend  website_visits  lead_volume     sales
# year
# 2023    0.000000e+00      95837676.0     333120.0  224883.0
# 2024    1.008047e+08     434938774.0    1313651.0  860219.0
# 2025    1.487976e+08     342431437.0     946134.0  639964.0

# %%
# Check zero ad spend
zero_ad_spend = df[df['total_ad_spend'] == 0]
print(f"Zero ad spend: {len(zero_ad_spend)}")
print(f"Zero ad spend percentage: {len(zero_ad_spend) / len(df) * 100:.2f}%")

with_ad_spend = df[df['total_ad_spend'] > 0]
print(f"With ad spend: {len(with_ad_spend)}")
print(f"With ad spend percentage: {len(with_ad_spend) / len(df) * 100:.2f}%")

# Compare sales with ad spend and without ad spend
print(f"\nAVG sales with ad spend: {with_ad_spend['sales'].mean():.2f}")
print(f"AVG sales without ad spend: {zero_ad_spend['sales'].mean():.2f}")
# Out:
# Zero ad spend: 28796
# Zero ad spend percentage: 46.96%
# With ad spend: 32526
# With ad spend percentage: 53.04%
#
# AVG sales with ad spend: 32.69
# AVG sales without ad spend: 22.99

# %%
# Create derived metrics

# Total Impressions
df['total_impressions'] = (df['search_ad_impressions'] + 
                          df['display_ad_impressions'] + 
                          df['social_ad_impressions'] + 
                          df['video_ad_impressions'] + 
                          df['pmax_ad_impressions'])

# Total Clicks
df['total_clicks'] = (df['search_ad_clicks'] + 
                      df['display_ad_clicks'] + 
                      df['social_ad_clicks'] + 
                      df['video_ad_clicks'] + 
                      df['pmax_ad_clicks'])

# CTR
df['ctr'] = np.where(df['total_impressions'] > 0, 
                    df['total_clicks'] / df['total_impressions'], 0)

# Conversion Rate
df['conversion_rate'] = np.where(df['website_visits'] > 0,
                                df['unique_lead_count'] / df['website_visits'], 0)

# Return on Ad Spend (ROAS)
df['roas'] = np.where(df['total_ad_spend'] > 0,
                     df['sales'] / df['total_ad_spend'], 0)

# %%
# Check new derived metrics
metrics_to_check = ['total_impressions', 'total_clicks', 'ctr', 'conversion_rate', 'roas']
print("=== New derived metrics ===")
print(df[metrics_to_check].describe())
# Out:
# === New derived metrics ===
#        total_impressions  total_clicks           ctr  conversion_rate  \
# count       6.132200e+04  6.132200e+04  61322.000000     61322.000000
# mean        2.786104e+05  3.882361e+03      0.285600         0.003479
# std         9.031047e+05  1.467906e+04     52.139270         0.029195
# min         0.000000e+00  0.000000e+00      0.000000         0.000000
# 25%         0.000000e+00  0.000000e+00      0.000000         0.001163
# 50%         0.000000e+00  2.900000e+01      0.000000         0.002096
# 75%         2.014455e+05  3.520000e+03      0.015078         0.003444
# max         8.352077e+07  2.691666e+06  12842.000000         3.000000
#
#                roas
# count  61322.000000
# mean       0.643156
# std       52.514714
# min        0.000000
# 25%        0.000000
# 50%        0.001138
# 75%        0.005980
# max    11400.000000

# %%
with_ad_spend = df[df['total_ad_spend'] > 0]
print(f"\n=== With ad spend ===")
print(f"Record: {len(with_ad_spend)}")
print(f"AVG CTR: {with_ad_spend['ctr'].mean():.4f}")
print(f"AVG Conversion Rate: {with_ad_spend['conversion_rate'].mean():.4f}")
print(f"AVG ROAS: {with_ad_spend['roas'].mean():.2f}")

# Conversion Rate Distribution
print(f"\nConversion Rate Distribution:")
print(f"Median: {df['conversion_rate'].median():.4f}")
print(f"75% Quantile: {df['conversion_rate'].quantile(0.75):.4f}")
print(f"90% Quantile: {df['conversion_rate'].quantile(0.9):.4f}")
# Out:
# === With ad spend ===
# Record: 32526
# AVG CTR: 0.5384
# AVG Conversion Rate: 0.0031
# AVG ROAS: 1.21
#
# Conversion Rate Distribution:
# Median: 0.0021
# 75% Quantile: 0.0034
# 90% Quantile: 0.0053

# %%
# AVG CTR: 0.5384 is too high, need to check
# Check abnormal CTR
print("=== CTR abnormal check ===")
print(f"CTR max: {df['ctr'].max():.4f}")
print(f"CTR median: {df['ctr'].median():.4f}")

# Check high CTR
high_ctr = df[df['ctr'] > 0.1]  # CTR > 10%
print(f"\nCTR > 10% records: {len(high_ctr)}")

if len(high_ctr) > 0:
    print("\nHigh CTR records:")
    sample = high_ctr[['store_id', 'month', 'total_impressions', 'total_clicks', 'ctr']].head()
    print(sample)
    
    # Check if there are records with clicks > impressions
    impossible = df[df['total_clicks'] > df['total_impressions']]
    print(f"\nRecords with clicks > impressions: {len(impossible)}")
    if len(impossible) > 0:
        print("Sample of these records:")
        print(impossible[['total_impressions', 'total_clicks', 'ctr']].head())
# Out:
# === CTR abnormal check ===
# CTR max: 12842.0000
# CTR median: 0.0000
#
# CTR > 10% records: 1491
#
# High CTR records:
#                                 dealer_id                     month  \
# 224  01555a1c-5b93-4717-b3df-842c96d7b520 2024-06-01 00:00:00+00:00
# 227  01555a1c-5b93-4717-b3df-842c96d7b520 2024-09-01 00:00:00+00:00
# 228  01555a1c-5b93-4717-b3df-842c96d7b520 2024-10-01 00:00:00+00:00
# 229  01555a1c-5b93-4717-b3df-842c96d7b520 2024-11-01 00:00:00+00:00
# 230  01555a1c-5b93-4717-b3df-842c96d7b520 2024-12-01 00:00:00+00:00
#
#      total_impressions  total_clicks       ctr
# 224            28338.0        4101.0  0.144717
# 227            20880.0        2615.0  0.125239
# 228             5479.0        1261.0  0.230151
# 229            12771.0        2512.0  0.196696
# 230            11147.0        2400.0  0.215305
#
# Records with clicks > impressions: 1891
# Sample of these records:
#      total_impressions  total_clicks  ctr
# 263                0.0         771.0  0.0
# 419                0.0         779.0  0.0
# 420                0.0        2832.0  0.0
# 421                0.0        2325.0  0.0
# 422                0.0        2720.0  0.0

# %%
# Check normal and abnormal records 
normal_records = df[df['total_clicks'] <= df['total_impressions']]
abnormal_records = df[df['total_clicks'] > df['total_impressions']]

print(f"Normal records: {len(normal_records)}")
print(f"Abnormal records: {len(abnormal_records)}")

if len(normal_records) > 0:
    print(f"\nNormal records average CTR: {normal_records['ctr'].mean():.4f}")
    print(f"Normal records CTR median: {normal_records['ctr'].median():.4f}")
# Out:
# Normal records: 59431
# Abnormal records: 1891
#
# Normal records average CTR: 0.0139
# Normal records CTR median: 0.0000

# %%
# Create derived metrics (df_clean)

# Step 1: Create cleaned dataset
df_clean = df.copy()

# Step 2: Recalculate derived metrics (using cleaned data)
df_clean['total_impressions'] = (df_clean['search_ad_impressions'] + 
                                df_clean['display_ad_impressions'] + 
                                df_clean['social_ad_impressions'] + 
                                df_clean['video_ad_impressions'] + 
                                df_clean['pmax_ad_impressions'])

df_clean['total_clicks'] = (df_clean['search_ad_clicks'] + 
                           df_clean['display_ad_clicks'] + 
                           df_clean['social_ad_clicks'] + 
                           df_clean['video_ad_clicks'] + 
                           df_clean['pmax_ad_clicks'])

# Step 3: Perform data cleaning
# Case 1: Zero impressions but non-zero clicks → Set clicks to 0
df_clean.loc[(df_clean['total_impressions'] == 0) & (df_clean['total_clicks'] > 0), 'total_clicks'] = 0

# Case 2: Clicks far exceed impressions → Limit CTR to reasonable range
df_clean['ctr_temp'] = np.where(df_clean['total_impressions'] > 0, 
                               df_clean['total_clicks'] / df_clean['total_impressions'], 0)

# ENHANCED: More aggressive CTR cleaning
# Limit CTR to 5% maximum (more realistic for most industries)
high_ctr_mask = df_clean['ctr_temp'] > 0.05
df_clean.loc[high_ctr_mask, 'total_clicks'] = df_clean.loc[high_ctr_mask, 'total_impressions'] * 0.05

# Additional cleaning: Remove records with impossible metrics
# Remove records where clicks > impressions (should not happen after cleaning)
impossible_mask = df_clean['total_clicks'] > df_clean['total_impressions']
df_clean.loc[impossible_mask, 'total_clicks'] = 0

# Step 4: Calculate final metrics
df_clean['ctr_clean'] = np.where(df_clean['total_impressions'] > 0, 
                                df_clean['total_clicks'] / df_clean['total_impressions'], 0)
# Conversion Rate
df_clean['conversion_rate'] = np.where(df_clean['website_visits'] > 0,
                                df_clean['unique_lead_count'] / df_clean['website_visits'], 0)

# Return on Ad Spend (ROAS)
df_clean['roas'] = np.where(df_clean['total_ad_spend'] > 0,
                     df_clean['sales'] / df_clean['total_ad_spend'], 0)

# %%
# Re-analyze conversion funnel with cleaned data
print("=== Conversion Funnel Analysis (After Cleaning) ===")
print(f"Average impressions: {df_clean['total_impressions'].mean():.0f}")
print(f"Average clicks: {df_clean['total_clicks'].mean():.0f}")
print(f"Average website visits: {df_clean['website_visits'].mean():.0f}")
print(f"Average leads: {df_clean['unique_lead_count'].mean():.0f}")
print(f"Average sales: {df_clean['sales'].mean():.0f}")

# CORRECTED: Recalculate conversion rates (using cleaned data)
# Note: Website visits include both paid and organic traffic, so we can't directly calculate click-to-visit conversion
df_clean['impression_to_click'] = np.where(df_clean['total_impressions'] > 0,
                                          df_clean['total_clicks'] / df_clean['total_impressions'], 0)

# CORRECTED: Calculate ad-driven visits (from clicks) vs total website visits
df_clean['ad_driven_visits'] = df_clean['search_ad_visits'] + df_clean['display_ad_visits'] + \
                              df_clean['social_ad_visits'] + df_clean['video_ad_visits'] + df_clean['pmax_ad_visits']

# FIXED: Calculate click-to-visit conversion properly
# Note: Ad visits should be less than or equal to clicks (not more)
df_clean['click_to_ad_visit'] = np.where(df_clean['total_clicks'] > 0,
                                        np.minimum(df_clean['ad_driven_visits'], df_clean['total_clicks']) / df_clean['total_clicks'], 0)

# Additional validation: Cap conversion rates at reasonable levels
df_clean['click_to_ad_visit'] = np.minimum(df_clean['click_to_ad_visit'], 1.0)  # Cap at 100%

# Website conversion rates (from total website visits)
df_clean['visit_to_unique_lead'] = np.where(df_clean['website_visits'] > 0,
                                    df_clean['unique_lead_count'] / df_clean['website_visits'], 0)
df_clean['visit_to_lead'] = np.where(df_clean['website_visits'] > 0,
                                    df_clean['lead_volume'] / df_clean['website_visits'], 0)
# FIXED: Lead to sale conversion - cap at reasonable levels
df_clean['lead_to_sale'] = np.where(df_clean['unique_lead_count'] > 0,
                                   df_clean['sales'] / df_clean['unique_lead_count'], 0)
# Cap lead-to-sale conversion at 200% (2.0) to handle data anomalies
df_clean['lead_to_sale'] = np.minimum(df_clean['lead_to_sale'], 2.0)

print(f"\nStage conversion rates:")
print(f"Impressions → Clicks: {df_clean['impression_to_click'].mean():.4f} ({df_clean['impression_to_click'].mean()*100:.2f}%)")
print(f"Clicks → Ad-Driven Visits: {df_clean['click_to_ad_visit'].mean():.4f} ({df_clean['click_to_ad_visit'].mean()*100:.2f}%)")
print(f"Website Visits → Leads: {df_clean['visit_to_lead'].mean():.4f} ({df_clean['visit_to_lead'].mean()*100:.2f}%)")
print(f"Website Visits → Unique Leads: {df_clean['visit_to_unique_lead'].mean():.4f} ({df_clean['visit_to_unique_lead'].mean()*100:.2f}%)")
print(f"Unique Leads → Sales: {df_clean['lead_to_sale'].mean():.4f} ({df_clean['lead_to_sale'].mean()*100:.2f}%)")

print(f"\nAdditional Metrics:")
print(f"Ad-driven visits as % of total visits: {(df_clean['ad_driven_visits'] / df_clean['website_visits']).mean():.4f} ({((df_clean['ad_driven_visits'] / df_clean['website_visits']).mean()*100):.2f}%)")
print(f"Organic visits as % of total visits: {((df_clean['website_visits'] - df_clean['ad_driven_visits']) / df_clean['website_visits']).mean():.4f} ({(((df_clean['website_visits'] - df_clean['ad_driven_visits']) / df_clean['website_visits']).mean()*100):.2f}%)")
# Out:
# === Conversion Funnel Analysis (After Cleaning) ===
# Average impressions: 278610
# Average clicks: 3774
# Average website visits: 14240
# Average leads: 36
# Average sales: 28
#
# Stage conversion rates:
# Impressions → Clicks: 0.0096 (0.96%)
# Clicks → Ad-Driven Visits: 0.3036 (30.36%)
# Website Visits → Leads: 0.0040 (0.40%)
# Website Visits → Unique Leads: 0.0035 (0.35%)
# Unique Leads → Sales: 0.9553 (95.53%)
#
# Additional Metrics:
# Ad-driven visits as % of total visits: 0.1374 (13.74%)
# Organic visits as % of total visits: 0.8626 (86.26%)

# %%
# Performance Metrics
df_clean['sales_per_visit'] = np.where(df_clean['website_visits'] > 0,
                                      df_clean['sales'] / df_clean['website_visits'], 0)

df_clean['cost_per_lead'] = np.where(df_clean['unique_lead_count'] > 0,
                                    df_clean['total_ad_spend'] / df_clean['unique_lead_count'], 0)

df_clean['leads_per_visit'] = np.where(df_clean['website_visits'] > 0,
                                      df_clean['unique_lead_count'] / df_clean['website_visits'], 0)

# Efficiency Metrics
df_clean['ad_efficiency'] = np.where(df_clean['total_ad_spend'] > 0,
                                    df_clean['total_clicks'] / df_clean['total_ad_spend'], 0)

df_clean['visit_efficiency'] = np.where(df_clean['total_clicks'] > 0,
                                       df_clean['website_visits'] / df_clean['total_clicks'], 0)

# Channel Mix Features (important for clustering)
df_clean['search_spend_ratio'] = np.where(df_clean['total_ad_spend'] > 0,
                                         df_clean['search_ad_spend'] / df_clean['total_ad_spend'], 0)

df_clean['social_spend_ratio'] = np.where(df_clean['total_ad_spend'] > 0,
                                         df_clean['social_ad_spend'] / df_clean['total_ad_spend'], 0)

df_clean['display_spend_ratio'] = np.where(df_clean['total_ad_spend'] > 0,
                                          df_clean['display_ad_spend'] / df_clean['total_ad_spend'], 0)

df_clean['video_spend_ratio'] = np.where(df_clean['total_ad_spend'] > 0,
                                        df_clean['video_ad_spend'] / df_clean['total_ad_spend'], 0)

df_clean['pmax_spend_ratio'] = np.where(df_clean['total_ad_spend'] > 0,
                                       df_clean['pmax_ad_spend'] / df_clean['total_ad_spend'], 0)

# Temporal Features
df_clean['is_holiday_season'] = df_clean['month_num'].isin([11, 12])
df_clean['is_quarter_end'] = df_clean['month_num'].isin([3, 6, 9, 12])
df_clean['is_summer'] = df_clean['month_num'].isin([6, 7, 8])

# %%
dealer_features = df_clean.groupby('store_id').agg({
    'sales': ['sum', 'mean', 'std', 'count'],
    'total_ad_spend': ['sum', 'mean'],
    'website_visits': ['sum', 'mean'],
    'unique_lead_count': ['sum', 'mean'],
    'ctr_clean': 'mean',
    'conversion_rate': 'mean',
    'roas': 'mean',
    'sales_per_visit': 'mean',
    'cost_per_lead': 'mean',
    'leads_per_visit': 'mean',
    'ad_efficiency': 'mean',
    'visit_efficiency': 'mean',
    'search_spend_ratio': 'mean',
    'social_spend_ratio': 'mean',
    'display_spend_ratio': 'mean',
    'video_spend_ratio': 'mean',
    'pmax_spend_ratio': 'mean',
    'is_holiday_season': 'mean', 
    'is_quarter_end': 'mean',
    'is_summer': 'mean',
    'month': 'nunique'  # months active
}).round(4)

# 3. Flatten column names
dealer_features.columns = ['_'.join(col).strip() for col in dealer_features.columns]
dealer_features = dealer_features.reset_index()

# 4. Add performance tiers
dealer_features['total_sales_tier'] = pd.cut(dealer_features['sales_sum'], 
                                            bins=3, labels=['Low', 'Medium', 'High'])
dealer_features['avg_roas_tier'] = pd.cut(dealer_features['roas_mean'], 
                                         bins=3, labels=['Low', 'Medium', 'High'])
dealer_features['conversion_tier'] = pd.cut(dealer_features['conversion_rate_mean'], 
                                           bins=3, labels=['Low', 'Medium', 'High'])

print("Dealer-level features created!")
print(f"Shape: {dealer_features.shape}")
print("\nColumns created:")
print(dealer_features.columns.tolist())
# Out:
# Dealer-level features created!
# Shape: (2557, 31)
#
# Columns created:
# ['dealer_id', 'sales_sum', 'sales_mean', 'sales_std', 'sales_count', 'total_ad_spend_sum', 'total_ad_spend_mean', 'website_visits_sum', 'website_visits_mean', 'unique_lead_count_sum', 'unique_lead_count_mean', 'ctr_clean_mean', 'conversion_rate_mean', 'roas_mean', 'sales_per_visit_mean', 'cost_per_lead_mean', 'leads_per_visit_mean', 'ad_efficiency_mean', 'visit_efficiency_mean', 'search_spend_ratio_mean', 'social_spend_ratio_mean', 'display_spend_ratio_mean', 'video_spend_ratio_mean', 'pmax_spend_ratio_mean', 'is_holiday_season_mean', 'is_quarter_end_mean', 'is_summer_mean', 'month_nunique', 'total_sales_tier', 'avg_roas_tier', 'conversion_tier']

# %%
# 4. Add performance tiers - Using improved tiering method
def create_performance_tiers(df, metric, n_tiers=3):
    """Create performance tiers - Relative ranking after excluding zero values"""
    # Exclude zero values for tiering
    non_zero = df[df[metric] > 0][metric]
    if len(non_zero) == 0:
        return pd.Series(['Zero'] * len(df), index=df.index)
    
    # Use quantile-based tiering
    q33 = non_zero.quantile(0.33)
    q67 = non_zero.quantile(0.67)
    
    def assign_tier(value):
        if value == 0:
            return 'Zero'
        elif value <= q33:
            return 'Low'
        elif value <= q67:
            return 'Medium'
        else:
            return 'High'
    
    return df[metric].apply(assign_tier)

# Create tiers for key metrics
dealer_features['total_sales_tier'] = create_performance_tiers(dealer_features, 'sales_sum')
dealer_features['avg_roas_tier'] = create_performance_tiers(dealer_features, 'roas_mean')
dealer_features['conversion_tier'] = create_performance_tiers(dealer_features, 'conversion_rate_mean')

print("Dealer-level features created with improved tiering!")
print(f"Shape: {dealer_features.shape}")
print("\nColumns created:")
print(dealer_features.columns.tolist())

# Check new tier distribution
print("\n=== New Tier Distribution ===")
print("Sales Tiers:")
print(dealer_features['total_sales_tier'].value_counts())
print("\nROAS Tiers:")
print(dealer_features['avg_roas_tier'].value_counts())
print("\nConversion Tiers:")
print(dealer_features['conversion_tier'].value_counts())
# Out:
# Dealer-level features created with improved tiering!
# Shape: (2557, 31)
#
# Columns created:
# ['dealer_id', 'sales_sum', 'sales_mean', 'sales_std', 'sales_count', 'total_ad_spend_sum', 'total_ad_spend_mean', 'website_visits_sum', 'website_visits_mean', 'unique_lead_count_sum', 'unique_lead_count_mean', 'ctr_clean_mean', 'conversion_rate_mean', 'roas_mean', 'sales_per_visit_mean', 'cost_per_lead_mean', 'leads_per_visit_mean', 'ad_efficiency_mean', 'visit_efficiency_mean', 'search_spend_ratio_mean', 'social_spend_ratio_mean', 'display_spend_ratio_mean', 'video_spend_ratio_mean', 'pmax_spend_ratio_mean', 'is_holiday_season_mean', 'is_quarter_end_mean', 'is_summer_mean', 'month_nunique', 'total_sales_tier', 'avg_roas_tier', 'conversion_tier']
#
# === New Tier Distribution ===
# Sales Tiers:
# total_sales_tier
# Medium    867
# Low       846
# High      842
# Zero        2
# Name: count, dtype: int64
#
# ROAS Tiers:
# avg_roas_tier
# Medium    832
# Low       820
# High      810
# Zero       95
# Name: count, dtype: int64
#
# Conversion Tiers:
# conversion_tier
# Medium    896
# Low       867
# High      778
# Zero       16
# Name: count, dtype: int64

# %%
# Prepare features for clustering
clustering_features = [
    'sales_mean', 'total_ad_spend_mean', 'website_visits_mean',
    'unique_lead_count_mean', 'ctr_clean_mean', 'conversion_rate_mean', 'roas_mean',
    'search_spend_ratio_mean', 'social_spend_ratio_mean', 'display_spend_ratio_mean',
    'video_spend_ratio_mean', 'pmax_spend_ratio_mean'
]

print(f"\n=== Feature distributions for clustering ===")
print(dealer_features[clustering_features].describe())
# Out:
# === Feature distributions for clustering ===
#         sales_mean  total_ad_spend_mean  website_visits_mean  \
# count  2557.000000          2557.000000          2557.000000
# mean     28.112812          4067.304583         14229.102203
# std      28.736634          6189.910753         14307.342653
# min       0.000000             0.000000             0.000000
# 25%       8.250000           487.372100          4185.166700
# 50%      18.666700          1956.151700         10086.666700
# 75%      38.750000          5114.491200         19966.083300
# max     284.041700         84857.485800        161026.125000
#
#        unique_lead_count_mean  ctr_clean_mean  conversion_rate_mean  \
# count             2557.000000     2557.000000           2557.000000
# mean                36.131274        0.009574              0.003477
# std                 45.997555        0.006594              0.011612
# min                  0.000000        0.000000              0.000000
# 25%                  7.916700        0.004300              0.001500
# 50%                 20.333300        0.008500              0.002300
# 75%                 47.625000        0.013300              0.003400
# max                692.166700        0.033300              0.395100
#
#          roas_mean  search_spend_ratio_mean  social_spend_ratio_mean  \
# count  2557.000000              2557.000000              2557.000000
# mean      0.642674                 0.208824                 0.143354
# std      10.819008                 0.188015                 0.115153
# min       0.000000                 0.000000                 0.000000
# 25%       0.002200                 0.000000                 0.054900
# 50%       0.006600                 0.199900                 0.123500
# 75%       0.030200                 0.367400                 0.208300
# max     481.456200                 0.666700                 0.624600
#
#        display_spend_ratio_mean  video_spend_ratio_mean  pmax_spend_ratio_mean
# count               2557.000000             2557.000000            2557.000000
# mean                   0.053940                0.004928               0.068823
# std                    0.084959                0.021961               0.090468
# min                    0.000000                0.000000               0.000000
# 25%                    0.000000                0.000000               0.000000
# 50%                    0.021300                0.000000               0.027200
# 75%                    0.063600                0.000000               0.107300
# max                    0.639000                0.500000               0.639700

# %%
# Save all processed data
df_clean.to_csv('../data/processed/store_kpi_clean.csv', index=False)
dealer_features.to_csv('../data/processed/dealer_features.csv', index=False)

print("All processed data saved!")
print(f"Individual records: {len(df_clean)}")
print(f"Dealer features: {len(dealer_features)}")
# Out:
# All processed data saved!
# Individual records: 61322
# Dealer features: 2557

# %%
# Enhance dealer features with ad activity metrics
import pandas as pd
import numpy as np
from pathlib import Path

RAW_CLEAN = '../data/processed/store_kpi_clean.csv'
OUTPUT_ENH = '../data/processed/dealer_features_enhanced.csv'

kpi = pd.read_csv(RAW_CLEAN)

# Ensure month_nunique exists or compute if needed (per dealer)
if 'month_nunique' not in kpi.columns:
    month_counts = kpi.groupby('store_id')['month'].nunique().rename('month_nunique')
    kpi = kpi.merge(month_counts, on='store_id', how='left')

# Activity flags
kpi['has_ad_spend'] = (kpi['total_ad_spend'] > 0).astype(int)
for ch in ['search','social','display','video','pmax']:
    col = f'{ch}_ad_spend'
    if col in kpi.columns:
        kpi[f'has_{ch}_spend'] = (kpi[col] > 0).astype(int)

# Active-only means helper
def active_mean(series, active_mask):
    vals = series[active_mask]
    return float(vals.mean()) if len(vals) > 0 else 0.0

agg_rows = []
for store_id, group in kpi.groupby('store_id'):
    month_n = group['month'].nunique() if 'month' in group.columns else group['month_num'].nunique()
    ad_active = int(group['has_ad_spend'].sum())
    ad_active_ratio = (ad_active / month_n) if month_n else 0.0
    spent_any = int(ad_active > 0)

    # active-only averages
    active_mask = group['has_ad_spend'] == 1
    avg_ad_spend_active_only = active_mean(group['total_ad_spend'], active_mask)

    ch_avgs = {}
    for ch in ['search','social','display','video','pmax']:
        spend_col = f'{ch}_ad_spend'
        if spend_col in group.columns:
            ch_avgs[f'{ch}_avg_spend_active_only'] = active_mean(group[spend_col], active_mask)

    # fall back to simple means if needed
    sales_sum = group['sales'].sum() if 'sales' in group.columns else np.nan
    sales_mean = group['sales'].mean() if 'sales' in group.columns else np.nan
    total_ad_spend_mean = group['total_ad_spend'].mean()
    website_visits_mean = group['website_visits'].mean()
    unique_lead_count_mean = group['unique_lead_count'].mean() if 'unique_lead_count' in group.columns else np.nan
    ctr_clean_mean = group['ctr_clean'].mean() if 'ctr_clean' in group.columns else np.nan
    conversion_rate_mean = group['conversion_rate'].mean() if 'conversion_rate' in group.columns else np.nan
    roas_mean = group['roas'].mean() if 'roas' in group.columns else np.nan

    # spend ratios average
    search_spend_ratio_mean = group['search_spend_ratio'].mean() if 'search_spend_ratio' in group.columns else 0.0
    social_spend_ratio_mean = group['social_spend_ratio'].mean() if 'social_spend_ratio' in group.columns else 0.0
    display_spend_ratio_mean = group['display_spend_ratio'].mean() if 'display_spend_ratio' in group.columns else 0.0
    video_spend_ratio_mean = group['video_spend_ratio'].mean() if 'video_spend_ratio' in group.columns else 0.0
    pmax_spend_ratio_mean = group['pmax_spend_ratio'].mean() if 'pmax_spend_ratio' in group.columns else 0.0

    row = {
        'store_id': store_id,
        'sales_sum': sales_sum,
        'sales_mean': sales_mean,
        'total_ad_spend_mean': total_ad_spend_mean,
        'website_visits_mean': website_visits_mean,
        'unique_lead_count_mean': unique_lead_count_mean,
        'ctr_clean_mean': ctr_clean_mean,
        'conversion_rate_mean': conversion_rate_mean,
        'roas_mean': roas_mean,
        'search_spend_ratio_mean': search_spend_ratio_mean,
        'social_spend_ratio_mean': social_spend_ratio_mean,
        'display_spend_ratio_mean': display_spend_ratio_mean,
        'video_spend_ratio_mean': video_spend_ratio_mean,
        'pmax_spend_ratio_mean': pmax_spend_ratio_mean,
        'month_nunique': month_n,
        'ad_months_active': ad_active,
        'ad_active_ratio': ad_active_ratio,
        'spent_any': spent_any,
        'avg_ad_spend_active_only': avg_ad_spend_active_only,
    }
    row.update(ch_avgs)
    agg_rows.append(row)

df_enh = pd.DataFrame(agg_rows)
# Write enhanced dealer features
Path(OUTPUT_ENH).parent.mkdir(parents=True, exist_ok=True)
df_enh.to_csv(OUTPUT_ENH, index=False)
print('Wrote', OUTPUT_ENH, 'shape=', df_enh.shape)

df_enh.head()
# Out:
# Wrote ../data/processed/dealer_features_enhanced.csv shape= (2557, 24)
#                               dealer_id  sales_sum  sales_mean  \
# 0  00033435-6a15-49e5-a1a1-cb5350c0cfc1      424.0   17.666667
# 1  0012401c-75c8-4e5b-87ca-c51172b14637      352.0   14.666667
# 2  001edcd2-e886-4e7d-b3bf-1f2244e0e790      646.0   26.916667
# 3  0062a118-fadc-4e33-b3b1-08a42bb25e67       96.0    4.000000
# 4  00a3403e-0779-4fe5-88f6-dee69ebf8101      103.0    4.291667
#
#    total_ad_spend_mean  website_visits_mean  unique_lead_count_mean  \
# 0          2349.726250         10214.916667               15.916667
# 1           718.460417         12421.375000               19.625000
# 2          4093.030417         11737.666667               31.000000
# 3           168.178750          4057.208333                5.541667
# 4           521.163750          2589.916667                5.708333
#
#    ctr_clean_mean  conversion_rate_mean  roas_mean  search_spend_ratio_mean  \
# 0        0.014413              0.001640   0.011929                 0.224002
# 1        0.008916              0.001679   0.840337                 0.000000
# 2        0.014960              0.002693   0.003912                 0.268540
# 3        0.003569              0.001416   0.006437                 0.000000
# 4        0.002050              0.004700   0.002401                 0.000000
#
#    ...  month_nunique  ad_months_active  ad_active_ratio  spent_any  \
# 0  ...             24                15         0.625000          1
# 1  ...             24                14         0.583333          1
# 2  ...             24                16         0.666667          1
# 3  ...             24                 7         0.291667          1
# 4  ...             24                 6         0.250000          1
#
#    avg_ad_spend_active_only  search_avg_spend_active_only  \
# 0               3759.562000                   2038.988000
# 1               1231.646428                      0.000000
# 2               6139.545625                   2441.776875
# 3                576.612857                      0.000000
# 4               2084.655000                      0.000000
#
#    social_avg_spend_active_only  display_avg_spend_active_only  \
# 0                    353.126667                     326.519335
# 1                    319.470714                      36.283571
# 2                   2361.464375                       9.397500
# 3                    566.642857                       9.970000
# 4                      0.000000                     533.356662
#
#    video_avg_spend_active_only  pmax_avg_spend_active_only
# 0                   107.048667                  354.748000
# 1                    17.042143                  854.133572
# 2                     0.000000                 1166.178762
# 3                     0.000000                    0.000000
# 4                   458.770000                 1092.528333
#
# [5 rows x 24 columns]
